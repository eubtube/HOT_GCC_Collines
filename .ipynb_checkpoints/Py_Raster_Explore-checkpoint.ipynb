# %%
import rasterio as rio

jaxa = rio.open('/media/eubtube/Seagate Backup Plus Drive/Congo_Tifs/raster/JAXA_DEM.tif')
jaxa

from rasterio.plot import show

show(jaxa)
# Out:
# <AxesSubplot:>

# %%
jaxa
# Out:
# <open DatasetReader name='/media/eubtube/Seagate Backup Plus Drive/Congo_Tifs/raster/JAXA_DEM.tif' mode='r'>

# %%
jaxa.width
# Out:
# 1068

# %%
jaxa.height
# Out:
# 768

# %%
jaxa.bounds
# Out:
# BoundingBox(left=769571.8822, bottom=9852459.1563, right=802631.9963, top=9876033.2776)

# %%
jaxa.transform * (0, 0)
# Out:
# (769571.8822, 9876033.2776)

# %%
jaxa.transform * (20,20)
# Out:
# (770190.9854602996, 9875419.368191145)

# %%
jaxa.crs
# Out:
# CRS.from_epsg(32735)

# %%
jaxa.indexes

band1 = jaxa.read(1)

# %%
from osgeo import gdal

help(gdal.ReprojectImage)

#gdal.ReprojectImage(src_ds, dst_ds, None, None, gdal.GRA_Bilinear)
# Out:
# Help on function ReprojectImage in module osgeo.gdal:
#
# ReprojectImage(*args, **kwargs)
#     ReprojectImage(Dataset src_ds, Dataset dst_ds, char const * src_wkt=None, char const * dst_wkt=None, GDALResampleAlg eResampleAlg, double WarpMemoryLimit=0.0, double maxerror=0.0, GDALProgressFunc callback=0, void * callback_data=None, char ** options=None) -> CPLErr

# %%
jaxa1 = gdal.Open('/media/eubtube/Seagate Backup Plus Drive/Congo_Tifs/raster/JAXA_DEM.tif')

jaxa_array = np.array(jaxa1.GetRasterBand(1).ReadAsArray())

jaxa_array
# Out:
# array([[   0, 1085, 1086, ...,    0,    0,    0],
#        [   0, 1085, 1086, ..., 1871, 1869, 1878],
#        [   0, 1085, 1086, ..., 1890, 1893, 1897],
#        ...,
#        [1614, 1616, 1617, ..., 2067, 2066,    0],
#        [1616, 1619, 1621, ..., 2070, 2068,    0],
#        [   0,    0,    0, ..., 2072, 2070,    0]], dtype=int16)

# %%
# This is the same as

# %%
import numpy as np
from scipy.signal import fftconvolve

def gaussian_blur(in_array, size):
    # expand in_array to fit edge of kernel
    padded_array = np.pad(in_array, size, 'symmetric')
    # build kernel
    x, y = np.mgrid[-size:size + 1, -size:size + 1]
    g = np.exp(-(x**2 / float(size) + y**2 / float(size)))
    g = (g / g.sum()).astype(in_array.dtype)
    # do the Gaussian blur
    return fftconvolve(padded_array, g, mode='valid')

gaussian_blur(, 100)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-1b568df42df2> in <module>
#      12     return fftconvolve(padded_array, g, mode='valid')
#      13
# ---> 14 gaussian_blur(jaxa, 100)
#
# <ipython-input-53-1b568df42df2> in gaussian_blur(in_array, size)
#       8     x, y = np.mgrid[-size:size + 1, -size:size + 1]
#       9     g = np.exp(-(x**2 / float(size) + y**2 / float(size)))
# ---> 10     g = (g / g.sum()).astype(in_array.dtype)
#      11     # do the Gaussian blur
#      12     return fftconvolve(padded_array, g, mode='valid')
#
# AttributeError: 'DatasetReader' object has no attribute 'dtype'
